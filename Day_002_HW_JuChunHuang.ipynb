# %% [markdown]
# ## [作業目標]
# 了解機器學習適合應用的領域與範疇。

# %% [markdown]
# ## [作業重點]
# 透過瞭解機器學習的運作方式，找出非常適用機器學習應用的領域及其原因

# %% [markdown]
# ## 作業
# 請找出一個你認為機器學習可以發光發熱的領域並闡述原因?

# %% [markdown]
# Answer:
# <br>
#
# Modern drug discovery is a costly and risky endeavor where
# failures in late-stage clinical trials still remain common,
# essentially negating all prior compound development investments. Therefore, computational Molecular Design uses machine learning method to identify and design molecular structures for the targeted use without spending much time on doing experiments.
